# %% [markdown]
# Things to do:
# * Date/Time
#     * verify dates are real (what to do with dates that are strange, e.g., pre-1900?)
# * split date and time (?)
# * convert times to UTC
# * duration
#     * split number and unit(e.g., seconds, minutes
#     * convert duration to milliseconds
# * location
#     * pull all non-location information out of location fields (i.e., city, state)
#     * add country column
#     * validate all 3 columns
# * summary information
#     * creates columns for nouns, adjectives, verbs (?)
#     * extra colors (new column)
# * factorize
#     * colors
#     * shapes
#
# References:
#
# https://towardsdatascience.com/machine-learning-nlp-text-classification-using-scikit-learn-python-and-nltk-c52b92a7c73a
#
# https://www.analyticsvidhya.com/blog/2020/12/understanding-text-classification-in-nlp-with-movie-review-example-example/
#
# https://blog.dataiku.com/text-classification-the-first-step-toward-nlp-mastery
#
# https://thinkinfi.com/complete-guide-for-natural-language-processing-in-python/
#
# https://towardsdatascience.com/nlp-in-python-vectorizing-a2b4fc1a339e

# %%
import pandas as pd
import numpy as np
import time
import logging
import nltk
import re
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
# !pip install contractions
import contractions

# !pip install country_list
import country_list
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Requirement already satisfied: contractions in /usr/local/lib/python3.6/site-packages (0.0.48)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.6/site-packages (from contractions) (0.0.21)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.6/site-packages (from textsearch>=0.0.21->contractions) (0.2.0)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.6/site-packages (from textsearch>=0.0.21->contractions) (1.4.2)
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/usr/local/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: country_list in /usr/local/lib/python3.6/site-packages (1.0.0)
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/usr/local/bin/python -m pip install --upgrade pip' command.

# %%
logging.basicConfig(filename='sightings_cleaning.log', format='%(asctime)s - %(message)s', datefmt='%d-%b-%y %H:%M:%S', level=logging.INFO)
logger = logging.getLogger()

# %%
def lemmatize_text(text):
    lemmatizer = WordNetLemmatizer()
    return ' '.join([lemmatizer.lemmatize(w) for w in text.split(' ')])

def expand_contractions(text):
    expanded_words = []    
    for word in text.split():
        expanded_words.append(contractions.fix(word))   

    return ' '.join(expanded_words)

def regex_clean(text):
    """
    Applies some pre-processing on the given text.

    Steps :
    - Removing HTML tags
    - Removing punctuation
    - Lowering text
    """
    
    # remove HTML tags
    text = re.sub(r'<.*?>', '', text)
    
    # remove the characters [\], ['] and ["]
    text = re.sub(r"\\", "", text)    
    text = re.sub(r"\'", "", text)    
    text = re.sub(r"\"", "", text)    
    
    # convert text to lowercase
    text = text.strip().lower()
    
    # replace punctuation characters with spaces
    filters='!"\'#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n'
    translate_dict = dict((c, " ") for c in filters)
    translate_map = str.maketrans(translate_dict)
    text = text.translate(translate_map)

    return text

def clean_text(text):
    stop = set(nltk.corpus.stopwords.words('english'))
    cleaned = expand_contractions(text.lower())
    # cleaned = regex_clean(text)
    tokens = word_tokenize(cleaned)
    cleaned = ' '.join([w for w in tokens if not w in stop])
    cleaned = lemmatize_text(cleaned)
    return cleaned

# %%
def load_clean_sightings_dataframe():
    file_name = "sightings.pkl"
    logger.info(f"Data read from {file_name}")
    sightings = pd.read_pickle(file_name)

    sightings = sightings[sightings['Summary'].str.contains('MADAR')==False]
    
    # The Detail_Summary column needs to be cleaned for the cleaning function to work.
    sightings["Detail_Summary"] = sightings["Detail_Summary"].fillna("")
    sightings.loc[sightings["Detail_Summary"] == "Summary detail page not found.", "Detail_Summary"] = ""

    sightings_cleaned = sightings.copy()
    sightings_cleaned['Detail_Summary_nltk'] = sightings_cleaned['Detail_Summary'].apply(clean_text)
    
    sightings_cleaned.to_pickle(cleaned_file_name)

# %%
cleaned_file_name = "sightings_cleaned.pkl"
start_fresh = False

if start_fresh:
    load_clean_sightings_dataframe()

# %% [markdown]
# In the next block we save the data to a file. The initial cleaning is on +95k records. This takes some time. In the remaining cleaning, if one messes up, as I have done quite a few times, they can re-run pd.read_pickle() which will restore the dataframe to the "just processed" phase.

# %%
sightings_cleaned = pd.read_pickle(cleaned_file_name)

# %%
sightings_cleaned.head()
# Out:
#        Date_Time            City State   Shape    Duration  \
# 0  4/23/21 06:30      Blackshear    GA  Circle   9 minutes
# 1  4/23/21 06:00  Mechanicsville    VA  Circle     Seconds
# 2  4/23/21 06:00      Vero Beach    FL   Light   5 minutes
# 3  4/23/21 05:59   St. Augustine    FL   Light   3 minutes
# 4  4/23/21 05:58          Durham    NC    Cone  >5 minutes
#
#                                              Summary   Posted  \
# 0  Very strange   ((NUFORC Note:  Rocket launch f...  4/23/21
# 1  Ball in the sky   ((NUFORC Note:  Rocket launc...  4/23/21
# 2  I was driving and saw something strange in the...  4/23/21
# 3  2 extremely bright lights appeared over east c...  4/23/21
# 4  A cone of light coming from the sky unlike any...  4/23/21
#
#                                          Detail_Link  \
# 0  http://www.nuforc.org/webreports/162/S162815.html
# 1  http://www.nuforc.org/webreports/162/S162814.html
# 2  http://www.nuforc.org/webreports/162/S162822.html
# 3  http://www.nuforc.org/webreports/162/S162824.html
# 4  http://www.nuforc.org/webreports/162/S162819.html
#
#                                       Detail_Summary  \
# 0  \nVery strangeI have recorded a video of this ...
# 1  \nBall in the skyObject appears as a white bal...
# 2  \nI was driving and saw something strange in t...
# 3  \n2 extremely bright lights appeared over east...
# 4  \nA cone of light coming from the sky unlike a...
#
#                                  Detail_Summary_nltk
# 0                   strangei recorded video sighting
# 1  ball skyobject appears white ball vapor strewi...
# 2  driving saw something strange sky pulled car i...
# 3  2 extremely bright light appeared east coast n...
# 4  cone light coming sky unlike anything ever see...

# %%
len(sightings_cleaned)
# Out:
# 95690

# %% [markdown]
# Do we want to remove the ones below with NUFORC notes? Perhaps someone could go through them to see what the notes are. Things like Starlink sightings should be removed. For now, the following block removes them otherwise nuforc and note dominate the wordcloud.

# %%
sightings_cleaned = sightings_cleaned[sightings_cleaned['Detail_Summary_nltk'].str.contains('nuforc note')==False]
sightings_cleaned = sightings_cleaned[sightings_cleaned['Detail_Summary_nltk'].str.contains('NUFORC note')==False]
sightings_cleaned = sightings_cleaned[sightings_cleaned['Detail_Summary_nltk'].str.contains('nuforc')==False]
sightings_cleaned = sightings_cleaned[sightings_cleaned['Detail_Summary_nltk'].str.contains('NUFORC')==False]
len(sightings_cleaned)
# Out:
# 67841

# %%
sightings_cleaned
# Out:
#            Date_Time                              City State      Shape  \
# 0      4/23/21 06:30                        Blackshear    GA     Circle
# 1      4/23/21 06:00                    Mechanicsville    VA     Circle
# 2      4/23/21 06:00                        Vero Beach    FL      Light
# 3      4/23/21 05:59                     St. Augustine    FL      Light
# 4      4/23/21 05:58                            Durham    NC       Cone
# 5      4/23/21 05:55                        I-16 south    GA     Sphere
# 6      4/23/21 05:54                           Parrish    FL      Light
# 7      4/23/21 05:45                    Champions Gate    FL      Light
# 9      4/23/21 02:40                         Firestone    CO    Chevron
# 10     4/22/21 22:23          New York City (Brooklyn)    NY   Fireball
# 11     4/22/21 21:00                 Firozabad (India)         Changing
# 12     4/22/21 20:50                          Appleton    WI   Triangle
# 13     4/22/21 20:42                            Dallas    GA      Light
# 14     4/22/21 00:00                       Oregon City    OR   Triangle
# 15     4/21/21 21:30                 Grandview Heights    OH      Light
# 16     4/21/21 21:25                          Eatonton    GA      Light
# 17     4/21/21 17:00                        Woodbridge    NJ    Unknown
# 18     4/21/21 04:30                            Payson    AZ      Light
# 19     4/20/21 23:43                             Brier    WA       Oval
# 20     4/20/21 23:00                          Bridgton    ME      Light
# 21     4/20/21 21:48                       Minneapolis    MN     Sphere
# 22     4/20/21 21:30                          Hartford    CT  Formation
# 23     4/20/21 21:00                            Dublin    PA   Fireball
# 24     4/20/21 20:30          New York City (Brooklyn)    NY      Flash
# 25     4/20/21 06:02                         San Mateo    CA      Light
# 26     4/19/21 22:00                         Glen Oaks    NY      Light
# 27     4/19/21 21:29                            Tulare    CA   Fireball
# 28     4/19/21 20:30                      West Chester            Cigar
# 29     4/19/21 14:49                          Marietta    GA     Circle
# 30     4/19/21 00:45                           Clarion    PA      Light
# ...              ...                               ...   ...        ...
# 97197                                         Subotica
# 97198                                         Richland    WA     Sphere
# 97199                                      Santa Maria    CA     Circle
# 97201                                             Rule    TX    Unknown
# 97202
# 97204                                     Warfordsburg    PA   Changing
# 97206                                       Jonesville    MI      Other
# 97211                                          Makawao    HI      Light
# 97213                                   North Carolina    NC      Flash
# 97215                                        Anchorage    AK  Rectangle
# 97216                                    Lake Elsinore    CA   Triangle
# 97217                                             Poca    WV     Circle
# 97219                                                     AZ
# 97220                                      Canyon City    CO      Other
# 97221                                                     IN
# 97223                                           Attica    IN
# 97225
# 97226                                           Hooper    CO     Circle
# 97228                                       Hellertown    PA
# 97229
# 97230                                           Warren    MI     Circle
# 97232                               Kitchener (Canada)    ON   Triangle
# 97233                                        Roseville    CA      Light
# 97237
# 97240                    Little Rock (5 miles west of)    AR    Unknown
# 97243                                        Littleton    CO       Disk
# 97244                                      Carson City    NV       Disk
# 97247                                       Gettysburg    PA     Sphere
# 97248                                         Ricetown    KY      Light
# 97249                 Long Island (Westchester County)    NY   Triangle
#
#                         Duration  \
# 0                      9 minutes
# 1                        Seconds
# 2                      5 minutes
# 3                      3 minutes
# 4                     >5 minutes
# 5                     10 minutes
# 6                      5 minutes
# 7                 ~10-15 minutes
# 9                    3-4 seconds
# 10                     2 minutes
# 11                     6 minutes
# 12                   20+ minutes
# 13                    45 seconds
# 14                   3-5 minutes
# 15
# 16                    15 seconds
# 17                   Few minutes
# 18                    10 minutes
# 19                    15 minutes
# 20                    10 minutes
# 21                     4 seconds
# 22                      1 minute
# 23                   1-2 minutes
# 24                  3:39 minutes
# 25                    12 seconds
# 26                     2 minutes
# 27                         21:32
# 28                    10 minutes
# 29                      1 minute
# 30                            30
# ...                          ...
# 97197
# 97198                     10 min
# 97199                      19:00
# 97201                 15 minutes
# 97202
# 97204  Minutes, maybe longer, it
# 97206
# 97211                  5 minutes
# 97213
# 97215                     5 mins
# 97216
# 97217       All night all summer
# 97219                 45 minutes
# 97220                 45 minutes
# 97221
# 97223
# 97225
# 97226                   1 minute
# 97228                  2 seconds
# 97229
# 97230
# 97232
# 97233
# 97237
# 97240                 25 minutes
# 97243                  2 seconds
# 97244                   1 minute
# 97247
# 97248                  5 minutes
# 97249                 30 seconds
#
#                                                  Summary    Posted  \
# 0      Very strange   ((NUFORC Note:  Rocket launch f...   4/23/21
# 1      Ball in the sky   ((NUFORC Note:  Rocket launc...   4/23/21
# 2      I was driving and saw something strange in the...   4/23/21
# 3      2 extremely bright lights appeared over east c...   4/23/21
# 4      A cone of light coming from the sky unlike any...   4/23/21
# 5      Noticed a intense light that was covering a la...   4/23/21
# 6      Two bright lights one flashing with a descendi...   4/23/21
# 7      Im former military and have never seen aircraf...   4/23/21
# 9      I witnessed a chevron-shaped object, silent an...   4/23/21
# 10     Saw a steady pulsating fireball above that mov...   4/23/21
# 11     Boomarang like shaped with five lights made a ...   4/23/21
# 12     metallic triangular shaped object appearing to...   4/23/21
# 13     12 red lights in the sky low to the horizon in...   4/23/21
# 14     A bright triangular shape hovering in sky obse...   4/23/21
# 15     Strange lights hovering low over Columbus.  ((...   4/23/21
# 16     For several months my husband and I watched a ...   4/23/21
# 17     UFO reported in central NJ affecting power/ele...   4/23/21
# 18             Bright light moving slowly across the sky   4/23/21
# 19     oval shaped, grey, hovering, no sound, fast ship.   4/23/21
# 20     I was outside at midnight on April 20th 2021 w...   4/23/21
# 21     Bright white sphere briefly materialized over ...   4/23/21
# 22     3 red bright light dots in line then form a tr...   4/23/21
# 23     Ball of light fastly flashes/transport into a ...   4/23/21
# 24     At approximately 8:30pm eastern time, I notice...   4/23/21
# 25                       420 morning zig zag white light   4/23/21
# 26                 Red pulsating orb low in sky over LIE   4/23/21
# 27                   I saw three unknown flying objects.   4/23/21
# 28     Crazy cigar shaped glowing object in suburban ...   4/23/21
# 29     Saw a large circular stationary object in broa...   4/23/21
# 30                        3 lights over the midnight sky   4/23/21
# ...                                                  ...       ...
# 97197  Objects was moving very fast on this about pos...    8/5/12
# 97198                                 Multiple sightings  12/20/12
# 97199  Watching Sunday or Monday night football went ...   1/31/20
# 97201  Unusual sounds and starlight distortion defini...   8/19/12
# 97202  In the movie, The Spy Who Dumped Me, there is ...   1/31/20
# 97204  I know it's strange to report a craft in the v...   1/19/21
# 97206                                 Several Abductions   8/23/19
# 97211  I a long chain of lights traveling across the ...   5/15/20
# 97213  Glowing red and blue Orb  ((NUFORC Note:  Witn...   4/23/21
# 97215  Around 2 in the morning went outside on my fro...   5/14/19
# 97216  There was a air craft that appeared triangular...   8/23/19
# 97217  I've reported this 3 times ,but it's never pos...  12/23/20
# 97219              Large Amber orb with pulsating light.   8/23/19
# 97220  look if been filming for almost two years to s...    8/6/20
# 97221  I just seen like 20 ufo ...they ufo people wil...   6/25/20
# 97223  A consistently appearing flying lighted uniden...   8/23/19
# 97225  Me and a friend were bow hunting early one mor...   6/25/20
# 97226  Two bright red and white lights moving across ...   9/19/19
# 97228  A hazy white oval witnessed by one person for ...   9/28/17
# 97229  At least two people were touched and have miss...   9/30/16
# 97230  I was laying a hgame on my phone and I looked ...   2/16/18
# 97232  Let w flying triangular craft..comp silence..f...    7/9/20
# 97233  Seeing a glowing of changing lights every nigh...  12/23/20
# 97237  This was after my sighting of 7 orange globes....  12/23/20
# 97240  A bright orange light hovering to the west of ...   1/31/20
# 97243              UFO disappears over cirrus formation.   1/11/19
# 97244   Spinning craft ( counter clockwise) I have video  12/23/20
# 97247  A hovering sphere shaped object that appeared ...    4/8/19
# 97248   Blinking lights weaving between trees in forest.    4/8/19
# 97249  From New Rochelle NY looking East in the sky, ...    4/9/20
#
#                                              Detail_Link  \
# 0      http://www.nuforc.org/webreports/162/S162815.html
# 1      http://www.nuforc.org/webreports/162/S162814.html
# 2      http://www.nuforc.org/webreports/162/S162822.html
# 3      http://www.nuforc.org/webreports/162/S162824.html
# 4      http://www.nuforc.org/webreports/162/S162819.html
# 5      http://www.nuforc.org/webreports/162/S162823.html
# 6      http://www.nuforc.org/webreports/162/S162820.html
# 7      http://www.nuforc.org/webreports/162/S162826.html
# 9      http://www.nuforc.org/webreports/162/S162827.html
# 10     http://www.nuforc.org/webreports/162/S162818.html
# 11     http://www.nuforc.org/webreports/162/S162804.html
# 12     http://www.nuforc.org/webreports/162/S162829.html
# 13     http://www.nuforc.org/webreports/162/S162817.html
# 14     http://www.nuforc.org/webreports/162/S162811.html
# 15     http://www.nuforc.org/webreports/162/S162802.html
# 16     http://www.nuforc.org/webreports/162/S162801.html
# 17     http://www.nuforc.org/webreports/162/S162813.html
# 18     http://www.nuforc.org/webreports/162/S162791.html
# 19     http://www.nuforc.org/webreports/162/S162816.html
# 20     http://www.nuforc.org/webreports/162/S162799.html
# 21     http://www.nuforc.org/webreports/162/S162793.html
# 22     http://www.nuforc.org/webreports/162/S162796.html
# 23     http://www.nuforc.org/webreports/162/S162777.html
# 24     http://www.nuforc.org/webreports/162/S162797.html
# 25     http://www.nuforc.org/webreports/162/S162794.html
# 26     http://www.nuforc.org/webreports/162/S162750.html
# 27     http://www.nuforc.org/webreports/162/S162798.html
# 28     http://www.nuforc.org/webreports/162/S162785.html
# 29     http://www.nuforc.org/webreports/162/S162769.html
# 30     http://www.nuforc.org/webreports/162/S162770.html
# ...                                                  ...
# 97197   http://www.nuforc.org/webreports/086/S86594.html
# 97198   http://www.nuforc.org/webreports/087/S87806.html
# 97199  http://www.nuforc.org/webreports/152/S152255.html
# 97201   http://www.nuforc.org/webreports/091/S91521.html
# 97202  http://www.nuforc.org/webreports/152/S152076.html
# 97204  http://www.nuforc.org/webreports/161/S161423.html
# 97206  http://www.nuforc.org/webreports/147/S147881.html
# 97211  http://www.nuforc.org/webreports/154/S154302.html
# 97213  http://www.nuforc.org/webreports/162/S162795.html
# 97215  http://www.nuforc.org/webreports/146/S146064.html
# 97216  http://www.nuforc.org/webreports/147/S147852.html
# 97217  http://www.nuforc.org/webreports/160/S160488.html
# 97219  http://www.nuforc.org/webreports/148/S148280.html
# 97220  http://www.nuforc.org/webreports/158/S158198.html
# 97221  http://www.nuforc.org/webreports/155/S155781.html
# 97223  http://www.nuforc.org/webreports/148/S148265.html
# 97225  http://www.nuforc.org/webreports/156/S156152.html
# 97226  http://www.nuforc.org/webreports/148/S148873.html
# 97228  http://www.nuforc.org/webreports/136/S136297.html
# 97229  http://www.nuforc.org/webreports/130/S130165.html
# 97230  http://www.nuforc.org/webreports/138/S138630.html
# 97232  http://www.nuforc.org/webreports/157/S157335.html
# 97233  http://www.nuforc.org/webreports/161/S161041.html
# 97237  http://www.nuforc.org/webreports/160/S160198.html
# 97240  http://www.nuforc.org/webreports/152/S152751.html
# 97243  http://www.nuforc.org/webreports/144/S144329.html
# 97244  http://www.nuforc.org/webreports/160/S160854.html
# 97247  http://www.nuforc.org/webreports/145/S145475.html
# 97248  http://www.nuforc.org/webreports/145/S145479.html
# 97249  http://www.nuforc.org/webreports/153/S153957.html
#
#                                           Detail_Summary  \
# 0      \nVery strangeI have recorded a video of this ...
# 1      \nBall in the skyObject appears as a white bal...
# 2      \nI was driving and saw something strange in t...
# 3      \n2 extremely bright lights appeared over east...
# 4      \nA cone of light coming from the sky unlike a...
# 5      \nDriving on I-16 south and noticed a intense ...
# 6      \nTwo bright lights one flashing with a descen...
# 7      \nIm former military and have never seen aircr...
# 9      \nI witnessed a chevron-shaped object, silent ...
# 10     \nSaw a steady pulsating fireball above that m...
# 11     \nBoomarang like shaped with five lights made ...
# 12     \nmetallic triangular shaped object appearing ...
# 13     \n12 red lights in the sky low to the horizon ...
# 14     \nA bright triangular shape hovering in sky ob...
# 15     \nStrange lights hovering low over ColumbusI'v...
# 16     \nFor several months my husband and I watched ...
# 17     \nUFO reported in central NJ affecting power/e...
# 18     \nBright light moving slowly across the skyWhi...
# 19     \noval shaped, grey, hovering, no sound, fast ...
# 20     \nI was outside at midnight on April 20th 2021...
# 21     \nBright white sphere briefly materialized ove...
# 22     \n3 red bright light dots in line then form a ...
# 23     \nBall of light fastly flashes/transport into ...
# 24     \nAt approximately 8:30pm eastern time, I noti...
# 25     \n420 morning zig zag white lightBright white ...
# 26     \nRed pulsating orb low in sky over LIEI was w...
# 27     \nI saw three unknown flying objects.I saw thr...
# 28     \nCrazy cigar shaped glowing object in suburba...
# 29     \nSaw a large circular stationary object in br...
# 30     \n3 lights over the midnight skyI was outside ...
# ...                                                  ...
# 97197  \nobjects was moving very fast on this about p...
# 97198  \nmultiple sightingsHello just heard ya on coa...
# 97199  \nWatching Sunday or Monday night football wen...
# 97201  \nUnusual sounds and starlight distortion defi...
# 97202  \nIn the movie, The Spy Who Dumped Me, there i...
# 97204  \nI know it's strange to report a craft in the...
# 97206  \nI was abducted several times all through my ...
# 97211  \nI a long chain of lights traveling across th...
# 97213  \nGlowing red and blue OrbAt first there was b...
# 97215
# 97216  \nThere was a air craft that appeared triangul...
# 97217  \nI've reported this 3 times ,but it's never p...
# 97219  \nLarge Amber orb with pulsating light.I was d...
# 97220  \nlook if been filming for almost two years to...
# 97221  \nI just seen like 20 ufo ...they ufo people w...
# 97223  \nA consistently appearing flying lighted unid...
# 97225  \nMe and a friend were bow hunting early one m...
# 97226  \nTwo bright red and white lights moving acros...
# 97228  \nA hazy white oval witnessed by one person fo...
# 97229  \nAt least two people were touched and have mi...
# 97230  \nI was laying a hgame on my phone and I looke...
# 97232  \nLet w flying triangular craft..comp silence....
# 97233  \nSeeing a glowing of changing lights every ni...
# 97237  \nThis was after my sighting of 7 orange globe...
# 97240  \nA bright orange light hovering to the west o...
# 97243  \nUFO disappears over cirrus formation.This mo...
# 97244  \nSpinning craft ( counter clockwise) I have v...
# 97247  \nA hovering sphere shaped object that appeare...
# 97248  \nBlinking lights weaving between trees in for...
# 97249  \nFrom New Rochelle NY looking East in the sky...
#
#                                      Detail_Summary_nltk
# 0                       strangei recorded video sighting
# 1      ball skyobject appears white ball vapor strewi...
# 2      driving saw something strange sky pulled car i...
# 3      2 extremely bright light appeared east coast n...
# 4      cone light coming sky unlike anything ever see...
# 5      driving i-16 south noticed intense light cover...
# 6      two bright light one flashing descending expan...
# 7      I former military never seen aircraft that.inc...
# 9      witnessed chevron-shaped object , silent seven...
# 10     saw steady pulsating fireball moved slowly awa...
# 11     boomarang like shaped five light made speed bi...
# 12     metallic triangular shaped object appearing tu...
# 13     12 red light sky low horizon paulding county ,...
# 14     bright triangular shape hovering sky observed ...
# 15     strange light hovering low columbusi 've watch...
# 16     several month husband watched strange light mo...
# 17     ufo reported central nj affecting power/electr...
# 18     bright light moving slowly across skywhile out...
# 19     oval shaped , grey , hovering , sound , fast s...
# 20     outside midnight april 20th 2021 saw think mul...
# 21     bright white sphere briefly materialized minne...
# 22     3 red bright light dot line form triangle form...
# 23     ball light fastly flashes/transport triangle ,...
# 24     approximately 8:30pm eastern time , noticed 1 ...
# 25     420 morning zig zag white lightbright white li...
# 26     red pulsating orb low sky liei westbound lie h...
# 27     saw three unknown flying objects.i saw three b...
# 28     crazy cigar shaped glowing object suburban pa....
# 29     saw large circular stationary object broad day...
# 30     3 light midnight skyi outside looked . seen th...
# ...                                                  ...
# 97197  object moving fast position sky 46 06 16,97n 1...
# 97198  multiple sightingshello heard ya coast coast ....
# 97199  watching sunday monday night football went out...
# 97201  unusual sound starlight distortion definitly i...
# 97202  movie , spy dumped , ufo . 2 woman running sho...
# 97204  know strange report craft vicinity place ficti...
# 97206  abducted several time child hood adulthood . c...
# 97211  long chain light traveling across sky perfectl...
# 97213  glowing red blue orbat first big bright light ...
# 97215
# 97216  air craft appeared triangular bold hazy blue l...
# 97217  I reported 3 time , never posted , many ufo ar...
# 97219  large amber orb pulsating light.i driving home...
# 97220  look filming almost two year say least see ufo...
# 97221  seen like 20 ufo ... ufo people tell something...
# 97223  consistently appearing flying lighted unidenti...
# 97225  friend bow hunting early one morning . sitting...
# 97226  two bright red white light moving across sky h...
# 97228  hazy white oval witnessed one person couple se...
# 97229  least two people touched missing time.no ufo '...
# 97230  laying hgame phone looked window saw 2 disk fl...
# 97232  let w flying triangular craft .. comp silence ...
# 97233  seeing glowing changing light every night appe...
# 97237  sighting 7 orange globes.it started year ago ....
# 97240  bright orange light hovering west property hig...
# 97243  ufo disappears cirrus formation.this morning a...
# 97244  spinning craft ( counter clockwise ) videoi sh...
# 97247  hovering sphere shaped object appeared spinnin...
# 97248  blinking light weaving tree forest.on back dec...
# 97249  new rochelle ny looking east sky , conn. & lon...
#
# [67841 rows x 10 columns]

# %% [markdown]
# The next section is cleaning up the city, state, and country column. To begin, we take cities that have () in them. We split that. Some of the parentheses have country or state in them, however, many do not have anything useful. Once cleaned, that needs to be merged back in and the general task of cleaning up the remaining location data may go forward.

# %%
sightings_cleaned[sightings_cleaned['City'].str.contains('\(')].City
# Out:
# 10                    New York City (Brooklyn)
# 11                           Firozabad (India)
# 24                    New York City (Brooklyn)
# 33                            Nanaimo (Canada)
# 95                     Merseyside (UK/England)
# 148                      Melbourne (Australia)
# 152                          Winnipeg (Canada)
# 203                         Gilching (Germany)
# 205                        Chilliwack (Canada)
# 215                          Langford (Canada)
# 223                     Vancouver Bc  (Canada)
# 306                           Oakbank (Canada)
# 309                         Rugby (UK/England)
# 344                      Tamworth (UK/England)
# 349                      New York City (Bronx)
# 365                           Calgary (Canada)
# 382                     Northwich (UK/England)
# 388                    Rosarito)(Baja)(Mexico)
# 398                         Monterrey (Mexico)
# 436                           Wiarton (Canada)
# 446                 Littlehampton (UK/England)
# 512                         Achumani (Bolivia)
# 545                       Mississauga (Canada)
# 557                   NEW WESTMINSTER (Canada)
# 558                             NYC (Brooklyn)
# 574                    Port Dalhousie (Canada)
# 577                   Cape Town (South Africa)
# 585                Thetford/Bradford (between)
# 593                     Auckland (New Zealand)
# 594                    Chichester (UK/England)
#                          ...
# 96793                          Mococa (Brasil)
# 96810                          Vernon (Canada)
# 96811                         Dublin (Ireland)
# 96864                   Auckland (New Zealand)
# 96866          Welwyn Garden City (UK/England)
# 96905              DEW Line (U. S. and Canada)
# 96913              Dugway (in the vicinity of)
# 96929               Barksdale AFB (Shreveport)
# 96945    Mount Pinos (beyond ski area parking)
# 96971                    New York City (Bronx)
# 96983                    Little America (near)
# 97013                         Yokohama (Japan)
# 97027                    Penuela (Puerto Rico)
# 97048                         Faraway (Canada)
# 97053                      Wadi Dhahal (Syria)
# 97054                        Fatima (Portugal)
# 97072       Maracaibo (outside of) (Venezuela)
# 97077                New York City (Manhattan)
# 97080                        Bounty (the ship)
# 97083          Muddy River (Brookline)(Boston)
# 97095                       Vancouver (Canada)
# 97100                   Newmarket (UK/England)
# 97112                          Kolkata (India)
# 97117                 New York City (Brooklyn)
# 97135                      London (UK/England)
# 97163                       Saskatoon (Canada)
# 97193                         Kelowna (Canada)
# 97232                       Kitchener (Canada)
# 97240            Little Rock (5 miles west of)
# 97249         Long Island (Westchester County)
# Name: City, Length: 7009, dtype: object

# %%
# df is a temporary dataframe so that I can clean cities with a () in them. The following is all of that work.
# Eventually, this could be merged into the main dataframe, or this code could be applied to that dataframe
# when we are confident it works.
df = sightings_cleaned[sightings_cleaned['City'].str.contains('\(')].City.str.split("\(([^)]+)", expand= True)
df.columns = ["City", "Country", "EndParenth", "Empty1", "Empty2", "Empty3", "Empty4"]
df.drop(["EndParenth"], axis=1, inplace = True)
df["City"] = df["City"].str.strip()
df

for index, row in df.iterrows():
    df.loc[index, "State"] = sightings_cleaned.loc[index].State

# %%
countries = dict(country_list.countries_for_language('en'))
cities_file = "us_cities_states_counties.csv"
cities_df = pd.read_csv(cities_file, delimiter="|")
city_list = cities_df.City.unique().tolist()
city_list[0:10]
# Out:
# ['Holtsville',
#  'Adjuntas',
#  'Aguada',
#  'Aguadilla',
#  'Maricao',
#  'Anasco',
#  'Angeles',
#  'Arecibo',
#  'Bajadero',
#  'Barceloneta']

# %%
countries
# Out:
# {'AF': 'Afghanistan',
#  'AX': 'Åland Islands',
#  'AL': 'Albania',
#  'DZ': 'Algeria',
#  'AS': 'American Samoa',
#  'AD': 'Andorra',
#  'AO': 'Angola',
#  'AI': 'Anguilla',
#  'AQ': 'Antarctica',
#  'AG': 'Antigua & Barbuda',
#  'AR': 'Argentina',
#  'AM': 'Armenia',
#  'AW': 'Aruba',
#  'AU': 'Australia',
#  'AT': 'Austria',
#  'AZ': 'Azerbaijan',
#  'BS': 'Bahamas',
#  'BH': 'Bahrain',
#  'BD': 'Bangladesh',
#  'BB': 'Barbados',
#  'BY': 'Belarus',
#  'BE': 'Belgium',
#  'BZ': 'Belize',
#  'BJ': 'Benin',
#  'BM': 'Bermuda',
#  'BT': 'Bhutan',
#  'BO': 'Bolivia',
#  'BA': 'Bosnia & Herzegovina',
#  'BW': 'Botswana',
#  'BV': 'Bouvet Island',
#  'BR': 'Brazil',
#  'IO': 'British Indian Ocean Territory',
#  'VG': 'British Virgin Islands',
#  'BN': 'Brunei',
#  'BG': 'Bulgaria',
#  'BF': 'Burkina Faso',
#  'BI': 'Burundi',
#  'KH': 'Cambodia',
#  'CM': 'Cameroon',
#  'CA': 'Canada',
#  'CV': 'Cape Verde',
#  'BQ': 'Caribbean Netherlands',
#  'KY': 'Cayman Islands',
#  'CF': 'Central African Republic',
#  'TD': 'Chad',
#  'CL': 'Chile',
#  'CN': 'China',
#  'CX': 'Christmas Island',
#  'CC': 'Cocos (Keeling) Islands',
#  'CO': 'Colombia',
#  'KM': 'Comoros',
#  'CG': 'Congo - Brazzaville',
#  'CD': 'Congo - Kinshasa',
#  'CK': 'Cook Islands',
#  'CR': 'Costa Rica',
#  'CI': 'Côte d’Ivoire',
#  'HR': 'Croatia',
#  'CU': 'Cuba',
#  'CW': 'Curaçao',
#  'CY': 'Cyprus',
#  'CZ': 'Czechia',
#  'DK': 'Denmark',
#  'DJ': 'Djibouti',
#  'DM': 'Dominica',
#  'DO': 'Dominican Republic',
#  'EC': 'Ecuador',
#  'EG': 'Egypt',
#  'SV': 'El Salvador',
#  'GQ': 'Equatorial Guinea',
#  'ER': 'Eritrea',
#  'EE': 'Estonia',
#  'SZ': 'Eswatini',
#  'ET': 'Ethiopia',
#  'FK': 'Falkland Islands',
#  'FO': 'Faroe Islands',
#  'FJ': 'Fiji',
#  'FI': 'Finland',
#  'FR': 'France',
#  'GF': 'French Guiana',
#  'PF': 'French Polynesia',
#  'TF': 'French Southern Territories',
#  'GA': 'Gabon',
#  'GM': 'Gambia',
#  'GE': 'Georgia',
#  'DE': 'Germany',
#  'GH': 'Ghana',
#  'GI': 'Gibraltar',
#  'GR': 'Greece',
#  'GL': 'Greenland',
#  'GD': 'Grenada',
#  'GP': 'Guadeloupe',
#  'GU': 'Guam',
#  'GT': 'Guatemala',
#  'GG': 'Guernsey',
#  'GN': 'Guinea',
#  'GW': 'Guinea-Bissau',
#  'GY': 'Guyana',
#  'HT': 'Haiti',
#  'HM': 'Heard & McDonald Islands',
#  'HN': 'Honduras',
#  'HK': 'Hong Kong SAR China',
#  'HU': 'Hungary',
#  'IS': 'Iceland',
#  'IN': 'India',
#  'ID': 'Indonesia',
#  'IR': 'Iran',
#  'IQ': 'Iraq',
#  'IE': 'Ireland',
#  'IM': 'Isle of Man',
#  'IL': 'Israel',
#  'IT': 'Italy',
#  'JM': 'Jamaica',
#  'JP': 'Japan',
#  'JE': 'Jersey',
#  'JO': 'Jordan',
#  'KZ': 'Kazakhstan',
#  'KE': 'Kenya',
#  'KI': 'Kiribati',
#  'KW': 'Kuwait',
#  'KG': 'Kyrgyzstan',
#  'LA': 'Laos',
#  'LV': 'Latvia',
#  'LB': 'Lebanon',
#  'LS': 'Lesotho',
#  'LR': 'Liberia',
#  'LY': 'Libya',
#  'LI': 'Liechtenstein',
#  'LT': 'Lithuania',
#  'LU': 'Luxembourg',
#  'MO': 'Macao SAR China',
#  'MG': 'Madagascar',
#  'MW': 'Malawi',
#  'MY': 'Malaysia',
#  'MV': 'Maldives',
#  'ML': 'Mali',
#  'MT': 'Malta',
#  'MH': 'Marshall Islands',
#  'MQ': 'Martinique',
#  'MR': 'Mauritania',
#  'MU': 'Mauritius',
#  'YT': 'Mayotte',
#  'MX': 'Mexico',
#  'FM': 'Micronesia',
#  'MD': 'Moldova',
#  'MC': 'Monaco',
#  'MN': 'Mongolia',
#  'ME': 'Montenegro',
#  'MS': 'Montserrat',
#  'MA': 'Morocco',
#  'MZ': 'Mozambique',
#  'MM': 'Myanmar (Burma)',
#  'NA': 'Namibia',
#  'NR': 'Nauru',
#  'NP': 'Nepal',
#  'NL': 'Netherlands',
#  'NC': 'New Caledonia',
#  'NZ': 'New Zealand',
#  'NI': 'Nicaragua',
#  'NE': 'Niger',
#  'NG': 'Nigeria',
#  'NU': 'Niue',
#  'NF': 'Norfolk Island',
#  'KP': 'North Korea',
#  'MK': 'North Macedonia',
#  'MP': 'Northern Mariana Islands',
#  'NO': 'Norway',
#  'OM': 'Oman',
#  'PK': 'Pakistan',
#  'PW': 'Palau',
#  'PS': 'Palestinian Territories',
#  'PA': 'Panama',
#  'PG': 'Papua New Guinea',
#  'PY': 'Paraguay',
#  'PE': 'Peru',
#  'PH': 'Philippines',
#  'PN': 'Pitcairn Islands',
#  'PL': 'Poland',
#  'PT': 'Portugal',
#  'PR': 'Puerto Rico',
#  'QA': 'Qatar',
#  'RE': 'Réunion',
#  'RO': 'Romania',
#  'RU': 'Russia',
#  'RW': 'Rwanda',
#  'WS': 'Samoa',
#  'SM': 'San Marino',
#  'ST': 'São Tomé & Príncipe',
#  'SA': 'Saudi Arabia',
#  'SN': 'Senegal',
#  'RS': 'Serbia',
#  'SC': 'Seychelles',
#  'SL': 'Sierra Leone',
#  'SG': 'Singapore',
#  'SX': 'Sint Maarten',
#  'SK': 'Slovakia',
#  'SI': 'Slovenia',
#  'SB': 'Solomon Islands',
#  'SO': 'Somalia',
#  'ZA': 'South Africa',
#  'GS': 'South Georgia & South Sandwich Islands',
#  'KR': 'South Korea',
#  'SS': 'South Sudan',
#  'ES': 'Spain',
#  'LK': 'Sri Lanka',
#  'BL': 'St. Barthélemy',
#  'SH': 'St. Helena',
#  'KN': 'St. Kitts & Nevis',
#  'LC': 'St. Lucia',
#  'MF': 'St. Martin',
#  'PM': 'St. Pierre & Miquelon',
#  'VC': 'St. Vincent & Grenadines',
#  'SD': 'Sudan',
#  'SR': 'Suriname',
#  'SJ': 'Svalbard & Jan Mayen',
#  'SE': 'Sweden',
#  'CH': 'Switzerland',
#  'SY': 'Syria',
#  'TW': 'Taiwan',
#  'TJ': 'Tajikistan',
#  'TZ': 'Tanzania',
#  'TH': 'Thailand',
#  'TL': 'Timor-Leste',
#  'TG': 'Togo',
#  'TK': 'Tokelau',
#  'TO': 'Tonga',
#  'TT': 'Trinidad & Tobago',
#  'TN': 'Tunisia',
#  'TR': 'Turkey',
#  'TM': 'Turkmenistan',
#  'TC': 'Turks & Caicos Islands',
#  'TV': 'Tuvalu',
#  'UM': 'U.S. Outlying Islands',
#  'VI': 'U.S. Virgin Islands',
#  'UG': 'Uganda',
#  'UA': 'Ukraine',
#  'AE': 'United Arab Emirates',
#  'GB': 'United Kingdom',
#  'US': 'United States',
#  'UY': 'Uruguay',
#  'UZ': 'Uzbekistan',
#  'VU': 'Vanuatu',
#  'VA': 'Vatican City',
#  'VE': 'Venezuela',
#  'VN': 'Vietnam',
#  'WF': 'Wallis & Futuna',
#  'EH': 'Western Sahara',
#  'YE': 'Yemen',
#  'ZM': 'Zambia',
#  'ZW': 'Zimbabwe'}

# %%
# This record is "NA" for the country. Have to fix that or the next few things will throw an error.
# Ask me how I know that.
df.loc[89338, "Country"] = "USA"

# %%
# Do we want these as England, Wales, etc.?
df.loc[df['Country'].str.contains('UK'), "Country"] = "United Kingdom"
df.loc[df['Country'].str.contains('Northern Ireland'), "Country"] = "United Kingdom"
df.loc[df['Country'].str.contains('UK'), 'Country'].unique()
# Out:
# array([], dtype=object)

# %%
df.loc[(df['Country'].isin(countries.values())==False)&(df.Empty1.isnull()==False), "Country"] = df["Empty1"]
df.loc[df['Country'].str.contains('Brooklyn'), "Country"] = "United States"
df.loc[df['Country'].str.contains('Bronx'), "Country"] = "United States"
df.loc[df['Country'].str.contains('Brookline'), "Country"] = "United States"
df.loc[df['Country'].str.contains('Westchester County'), "Country"] = "United States"
df.loc[df['Country'].str.contains('Baja'), "Country"] = "Mexico"
df.loc[df['Country'].str.contains('Manhattan'), "Country"] = "United States"
df.loc[df['Country'].str.contains('Bronx'), "Country"] = "United States"
df.loc[df['Country'].str.contains('Queens'), "Country"] = "United States"
df.loc[df['Country'].str.contains('Watts'), "Country"] = "United States"
df.loc[df['City'].str.contains('Warsaw/Clinton'), "Country"] = "United States"
df.loc[df['Country'].str.contains('USA'), "Country"] = "United States"
df.loc[df['Country'].str.contains('Calgary'), "Country"] = "Canada"
df.loc[df['Country'].str.contains('Wilhelmsburg'), "Country"] = "Germany"
df.loc[df['Country'].str.contains('Czech Republic'), "Country"] = "Czechia"
df.loc[df['Country'].str.contains('Punjab'), "Country"] = "India"
df.loc[df['Country'].str.contains('West Germany'), "Country"] = "Germany"
df.loc[df.Empty1 == "Canada", "Country"] = "Canada"
df.loc[df['Country'].str.contains('Brasil'), "Country"] = "Brazil"
df.loc[df['Country'].str.contains('Macedonia'), "Country"] = "North Macedonia"
df.loc[df['Country'].str.contains('México'), "Country"] = "Mexico"

# %%
df[(df['Country'].isin(countries.values())==False)&(df['City'].isin(cities_df.City))].Empty1.unique()
# Out:
# array(['in-flight', None, '"Abiquiu"', 'Northern Ireland', 'UK/England',
#        'UK/Scotland', 'Victoria', 'pilot report', 'Riverside',
#        'Republic of South Africa', 'UK/Wales', 'near', 'in flight'],
#       dtype=object)

# %%
df[(df['Country'].isin(countries.values())==False)&(df['City'].isin(cities_df.City))].Empty2.unique()
# Out:
# array([')', None, ''], dtype=object)

# %%
df[(df['Country'].isin(countries.values())==False)&(df['City'].isin(cities_df.City))].Empty3.unique()
# Out:
# array([None, 'Australia'], dtype=object)

# %%
df[(df['Country'].isin(countries.values())==False)&(df['City'].isin(cities_df.City))].Empty4.unique()
# Out:
# array([None, ')'], dtype=object)

# %%
# Country not in Country list
# Cities not in the US city list
# cities_df[cities_df.City == "Canada"] ----> Canada is a city in Kentucky
# df[(df['Country'].isin(countries.values())==False)]

# Cities in the US city list
#df[(df['Country'].isin(countries.values())==False)&(df['City'].isin(cities_df.City)), "Country"] = "United States"
df.loc[df['Empty1'].isnull(), "Empty1"] = " "
df.loc[df['Empty2'].isnull(), "Empty2"] = " "
df.loc[df['Empty3'].isnull(), "Empty3"] = " "
df.loc[df['Empty4'].isnull(), "Empty4"] = " "
df.loc[df['Empty3'].str.contains('Australia'), "Country"] = "Australia"
df.loc[df['Empty1'].str.contains('Northern Ireland'), "Country"] = "United Kingdom"
df.loc[df['Empty1'].str.contains('UK/England'), "Country"] = "United Kingdom"
df.loc[df['Empty1'].str.contains('UK/Wales'), "Country"] = "United Kingdom"
df.loc[df['Empty1'].str.contains('UK/Scotland'), "Country"] = "United Kingdom"
df.loc[df['Empty1'].str.contains('Republic of South Africa'), "Country"] = "South Africa"

# %%
df.drop(["Empty1", "Empty2", "Empty3", "Empty4"], axis=1, inplace=True)

# %%
df.loc[(df['Country'].isin(countries.values())==False)&(df['City'].isin(cities_df.City)), "Country"] = "United States"

# %%
df.loc[(df['Country'].isin(countries.values())==False)&(df['City'].isin(cities_df.City)==False)]
# Out:
#                               City                              Country State
# 585              Thetford/Bradford                              between    VT
# 848                 Ras Al Khaimah                                  UAR
# 1101                        Urjala                            Finland??    AK
# 1999                    St. George                             north of    UT
# 2162                                             Unspecified by witness    KY
# 2363             Las Vegas/Ryolite                              between    NV
# 3274                  Lake Kachess                     Easbound on I-90    WA
# 3754                 NoLos Angeles                         northeast of    CA
# 4280         Pearl Lake State Park  25 miles north of Steamboat Springs    CO
# 4445              West Los Angeles                            Brentwood    CA
# 4453          Jonestown/Logo Vista                              between    TX
# 4487                  New Yor City                      Jamaica  queens    NY
# 4702                       Kyrenia                      Northern Cyprus
# 4774                      Armadale                    Western Australia
# 5348                   St. Charles                                    ?    MN
# 5882                      In Space                         from the ISS
# 6019                Burlington Co.           Presidential Lakes Estates    NJ
# 7075                 Val-des-Monts                            St-Pierre    QC
# 7092                      Osssipee                                    ?    NH
# 7100               Upper Makefield                 Above Delaware River    PA
# 7219                 Playa Guiones                            Costa Rca
# 7383    Mountain Home/Glenns Ferry                              between    ID
# 7900                    St. Thomas                                 USVI
# 7924                        Volcan                   Republic of Panama
# 8131                      Kamloops                             Kamloops    BC
# 8156                     Augustine                                   at    FL
# 8307                       Laktasi                   Bosnia/Herzegovina
# 8399                      Sarajevo                               Bosnia
# 8828            Medellin, Colombia                           El Poblado
# 9043            Indianola/Canadian                              between    OK
# ...                            ...                                  ...   ...
# 93454                    In-flight             from Las Vegas to Hawaii    NV
# 93578                      Abiline                            Dyess AFB    CA
# 93816                  Golden Pond                                 near    KY
# 93982                    Abu Dhabi                                  UAE
# 94146                  Mt. Rainier               east slope; ~6,500 ASL    WA
# 94159                     Fagstaff                             north of    AZ
# 94360                        Doboj                               Bosnia
# 94486                       France                     rural; northern
# 94557              Victory Heights                             Franklin    PA
# 94582  Jacksonville Flat & Atlanta                              between    GA
# 94593       Clines Corners/Tijeras                              between    NM
# 94613                        Tonga                 unspecified location
# 94754                    Australia                            in-flight
# 94772              Padstow Heights                            Austra;ia
# 94786                  Mississippi                                rural    MS
# 94830           Las Cruces/Soccoro                              between    NM
# 94896             Carlsbad Cavrans                                 near    NM
# 95003          Smith Mountain Lake              near Gretna and Penhook    VA
# 95763               Philippine Sea                               at sea
# 95768                      Georgia                                rural    GA
# 95997                    Quang Tri                             Viet Nam
# 96126              Franconia Notch                                 near    NH
# 96170                 Azusa Canyon                                    ?    CA
# 96267                     Viet Nam      3 mi. off coast of; aboard ship
# 96482                     Cotullia                                 near    TX
# 96624              Lawrence County              rural agriculture field    IL
# 96905                     DEW Line                     U. S. and Canada
# 96945                  Mount Pinos              beyond ski area parking    CA
# 97080                       Bounty                             the ship
# 97083                  Muddy River                               Boston    MA
#
# [590 rows x 3 columns]

# %% [markdown]
# df needs to be merged back into sightings_cleaned then saved to the file.

# %%
sightings_cleaned.to_pickle(cleaned_file_name)

# %%
sightings_cleaned.head()
# Out:
#        Date_Time            City State   Shape    Duration  \
# 0  4/23/21 06:30      Blackshear    GA  Circle   9 minutes
# 1  4/23/21 06:00  Mechanicsville    VA  Circle     Seconds
# 2  4/23/21 06:00      Vero Beach    FL   Light   5 minutes
# 3  4/23/21 05:59   St. Augustine    FL   Light   3 minutes
# 4  4/23/21 05:58          Durham    NC    Cone  >5 minutes
#
#                                              Summary   Posted  \
# 0  Very strange   ((NUFORC Note:  Rocket launch f...  4/23/21
# 1  Ball in the sky   ((NUFORC Note:  Rocket launc...  4/23/21
# 2  I was driving and saw something strange in the...  4/23/21
# 3  2 extremely bright lights appeared over east c...  4/23/21
# 4  A cone of light coming from the sky unlike any...  4/23/21
#
#                                          Detail_Link  \
# 0  http://www.nuforc.org/webreports/162/S162815.html
# 1  http://www.nuforc.org/webreports/162/S162814.html
# 2  http://www.nuforc.org/webreports/162/S162822.html
# 3  http://www.nuforc.org/webreports/162/S162824.html
# 4  http://www.nuforc.org/webreports/162/S162819.html
#
#                                       Detail_Summary  \
# 0  \nVery strangeI have recorded a video of this ...
# 1  \nBall in the skyObject appears as a white bal...
# 2  \nI was driving and saw something strange in t...
# 3  \n2 extremely bright lights appeared over east...
# 4  \nA cone of light coming from the sky unlike a...
#
#                                  Detail_Summary_nltk
# 0                   strangei recorded video sighting
# 1  ball skyobject appears white ball vapor strewi...
# 2  driving saw something strange sky pulled car i...
# 3  2 extremely bright light appeared east coast n...
# 4  cone light coming sky unlike anything ever see...
